# %% [markdown]
# # HR

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/HR%20Data-%20HR%20data.csv
# Out:
# --2025-02-02 20:15:05--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/HR%20Data-%20HR%20data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 286047 (279K) [text/plain]
# Saving to: ‘HR Data- HR data.csv’
#
# HR Data- HR data.cs 100%[===================>] 279.34K  --.-KB/s    in 0.03s
#
# 2025-02-02 20:15:05 (10.5 MB/s) - ‘HR Data- HR data.csv’ saved [286047/286047]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/HR Data- HR data.csv')

# %%
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
df.describe()
# Out:
#        Employee Number  Training Times Last Year          Age  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.799320    36.923810
# std         602.024335                  1.289271     9.135373
# min           1.000000                  0.000000    18.000000
# 25%         491.250000                  2.000000    30.000000
# 50%        1020.500000                  3.000000    36.000000
# 75%        1555.750000                  3.000000    43.000000
# max        2068.000000                  6.000000    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# std               0.367863   403.509100            8.106864             0.0
# min               0.000000   102.000000            1.000000             1.0
# ...

# %%
df.isna().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# ...

# %%
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

df_train, df_test = train_test_split(df, test_size=0.1, random_state=42)
df_train.head(3)
# Out:
#     Attrition    Business Travel CF_age band CF_attrition label Department  \
# 915       Yes  Travel_Frequently    Under 25       Ex-Employees        R&D
# 101        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 107       Yes      Travel_Rarely     25 - 34       Ex-Employees      Sales
#
#     Education Field      emp no  Employee Number  Gender  \
# 915   Life Sciences  STAFF-1279             1279  Female
# 101   Life Sciences   STAFF-134              134    Male
# 107       Marketing   STAFF-142              142    Male
#
#                   Job Role Marital Status Over Time Over18  \
# 915  Laboratory Technician         Single        No      Y
# 101     Research Scientist         Single        No      Y
# 107        Sales Executive         Single       Yes      Y
#
#      Training Times Last Year  Age  CF_current Employee  Daily Rate  \
# 915                         2   21                    0         251
# ...

# %%
df_train.shape, df_test.shape
# Out:
# ((1323, 39), (147, 39))

# %%
df['Education'].value_counts()
# Out:
# Education
# Bachelor's Degree    572
# Master's Degree      398
# Associates Degree    282
# High School          170
# Doctoral Degree       48
# Name: count, dtype: int64

# %%
target_cols = ['Attrition']

cat_cols = ['Business Travel', 'CF_age band',
       'Department', 'Education Field', 'Gender', 'Job Role', 'Marital Status',
       'Over Time', 'Education', 'Environment Satisfaction',
       'Job Involvement', 'Job Level', 'Job Satisfaction',
       'Performance Rating', 'Relationship Satisfaction',
       'Stock Option Level', 'Work Life Balance']

num_cols = list(set(df.columns).difference(target_cols+cat_cols))
num_cols
# Out:
# ['Years Since Last Promotion',
#  'CF_attrition label',
#  'Hourly Rate',
#  'Years At Company',
#  'Employee Number',
#  'Years In Current Role',
#  'Employee Count',
#  'Monthly Rate',
#  'Distance From Home',
#  'Total Working Years',
#  'Num Companies Worked',
#  'Daily Rate',
#  'Training Times Last Year',
#  'Percent Salary Hike',
#  'Over18',
#  'CF_current Employee',
#  'emp no',
#  'Age',
#  'Monthly Income',
#  'Years With Curr Manager',
#  'Standard Hours']

# %%
df[num_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Years Since Last Promotion  1470 non-null   int64
#  1   CF_attrition label          1470 non-null   object
#  2   Hourly Rate                 1470 non-null   int64
#  3   Years At Company            1470 non-null   int64
#  4   Employee Number             1470 non-null   int64
#  5   Years In Current Role       1470 non-null   int64
#  6   Employee Count              1470 non-null   int64
#  7   Monthly Rate                1470 non-null   int64
#  8   Distance From Home          1470 non-null   int64
#  9   Total Working Years         1470 non-null   int64
#  10  Num Companies Worked        1470 non-null   int64
#  11  Daily Rate                  1470 non-null   int64
#  12  Training Times Last Year    1470 non-null   int64
# ...

# %%
df[cat_cols]
# Out:
#         Business Travel CF_age band Department   Education Field  Gender  \
# 0         Travel_Rarely     35 - 44      Sales     Life Sciences  Female
# 1     Travel_Frequently     45 - 54        R&D     Life Sciences    Male
# 2         Travel_Rarely     35 - 44        R&D             Other    Male
# 3     Travel_Frequently     25 - 34        R&D     Life Sciences  Female
# 4         Travel_Rarely     25 - 34        R&D           Medical    Male
# ...                 ...         ...        ...               ...     ...
# 1465         Non-Travel     25 - 34        R&D  Technical Degree    Male
# 1466  Travel_Frequently     25 - 34        R&D     Life Sciences    Male
# 1467  Travel_Frequently     35 - 44      Sales             Other    Male
# 1468      Travel_Rarely    Under 25        R&D     Life Sciences    Male
# 1469      Travel_Rarely    Under 25      Sales     Life Sciences    Male
#
#                    Job Role Marital Status Over Time          Education  \
# ...

# %%
df[cat_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Business Travel            1470 non-null   object
#  1   CF_age band                1470 non-null   object
#  2   Department                 1470 non-null   object
#  3   Education Field            1470 non-null   object
#  4   Gender                     1470 non-null   object
#  5   Job Role                   1470 non-null   object
#  6   Marital Status             1470 non-null   object
#  7   Over Time                  1470 non-null   object
#  8   Education                  1470 non-null   object
#  9   Environment Satisfaction   1470 non-null   int64
#  10  Job Involvement            1470 non-null   int64
#  11  Job Level                  1470 non-null   int64
#  12  Job Satisfaction           1470 non-null   int64
# ...

# %%
for col in cat_cols:
  print(f'\n{col}:')
  print(df[col].value_counts(dropna=False))
# Out:
# Business Travel:
# Business Travel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# CF_age band:
# CF_age band
# 25 - 34     554
# 35 - 44     505
# 45 - 54     245
# Under 25     97
# Over 55      69
# Name: count, dtype: int64
#
# Department:
# Department
# R&D      961
# Sales    446
# HR        63
# Name: count, dtype: int64
#
# Education Field:
# Education Field
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# Gender:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
# Job Role:
# Job Role
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# ...
